# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
## SEntences
sentences = ['the cat sat on the mat',
            'the dog sat on the log',
            'the cat sat on the log']
sentences
# Out:
# ['the cat sat on the mat', 'the dog sat on the log', 'the cat sat on the log']

# %%
## Define Vocabulary Size
voc_size = 10000

# %%
## One Hot Representation
onehot_repr = [one_hot(words, voc_size) for words in sentences]
onehot_repr
# Out:
# [[1076, 5093, 2939, 5468, 1076, 7889],
#  [1076, 1011, 2939, 5468, 1076, 6184],
#  [1076, 5093, 2939, 5468, 1076, 6184]]

# %%
## Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_size = 8
embedded_docs = pad_sequences(onehot_repr, padding='pre', maxlen=sent_size)
embedded_docs
# Out:
# array([[   0,    0, 1076, 5093, 2939, 5468, 1076, 7889],
#        [   0,    0, 1076, 1011, 2939, 5468, 1076, 6184],
#        [   0,    0, 1076, 5093, 2939, 5468, 1076, 6184]], dtype=int32)

# %%
## Feature Representation
dim = 10
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_size))
model.compile('adam', 'mse')
model.build((None, sent_size))
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# array([[[ 0.01264148, -0.01885283, -0.00728496,  0.03434764,
#          -0.01099346,  0.00751543,  0.03325385,  0.03097752,
#           0.03303529,  0.04536482],
#         [ 0.01264148, -0.01885283, -0.00728496,  0.03434764,
#          -0.01099346,  0.00751543,  0.03325385,  0.03097752,
#           0.03303529,  0.04536482],
#         [-0.04993763, -0.00936762, -0.03285591, -0.00137503,
#          -0.04254065, -0.00520714, -0.02135353,  0.02181954,
#           0.02116657,  0.02434163],
#         [-0.03057574,  0.01116729, -0.03806347,  0.03410003,
#          -0.0133304 , -0.04821406, -0.02268374, -0.02588072,
#          -0.00587511, -0.04017673],
#         [ 0.0029979 ,  0.04305224,  0.04474748, -0.00748608,
#          -0.03005732,  0.02354633, -0.00489905, -0.02228575,
#           0.03264082,  0.0431743 ],
#         [ 0.03630084, -0.01648297,  0.02003438,  0.00955741,
#          -0.0211835 , -0.0315058 ,  0.02355404, -0.04800181,
#           0.03998161,  0.02602788],
#         [-0.04993763, -0.00936762, -0.03285591, -0.00137503,
#          -0.04254065, -0.00520714, -0.02135353,  0.02181954,
#           0.02116657,  0.02434163],
#         [ 0.02854744, -0.03522245, -0.01637282, -0.03720391,
#          -0.01939701,  0.03225539, -0.04861646, -0.04099549,
#           0.04122878, -0.01252142]],
#
#        [[ 0.01264148, -0.01885283, -0.00728496,  0.03434764,
#          -0.01099346,  0.00751543,  0.03325385,  0.03097752,
#           0.03303529,  0.04536482],
#         [ 0.01264148, -0.01885283, -0.00728496,  0.03434764,
#          -0.01099346,  0.00751543,  0.03325385,  0.03097752,
#           0.03303529,  0.04536482],
#         [-0.04993763, -0.00936762, -0.03285591, -0.00137503,
#          -0.04254065, -0.00520714, -0.02135353,  0.02181954,
#           0.02116657,  0.02434163],
#         [ 0.03325163, -0.04511293, -0.01930119,  0.02796686,
#          -0.03980057, -0.02320245,  0.03338642, -0.02217586,
#          -0.0056247 ,  0.03405834],
#         [ 0.0029979 ,  0.04305224,  0.04474748, -0.00748608,
#          -0.03005732,  0.02354633, -0.00489905, -0.02228575,
#           0.03264082,  0.0431743 ],
#         [ 0.03630084, -0.01648297,  0.02003438,  0.00955741,
#          -0.0211835 , -0.0315058 ,  0.02355404, -0.04800181,
#           0.03998161,  0.02602788],
#         [-0.04993763, -0.00936762, -0.03285591, -0.00137503,
#          -0.04254065, -0.00520714, -0.02135353,  0.02181954,
#           0.02116657,  0.02434163],
#         [-0.04222417, -0.03720592, -0.02691523, -0.02534245,
#          -0.0433336 ,  0.04460852,  0.0320389 , -0.03661418,
#           0.03061563,  0.01801929]],
#
#        [[ 0.01264148, -0.01885283, -0.00728496,  0.03434764,
#          -0.01099346,  0.00751543,  0.03325385,  0.03097752,
#           0.03303529,  0.04536482],
#         [ 0.01264148, -0.01885283, -0.00728496,  0.03434764,
#          -0.01099346,  0.00751543,  0.03325385,  0.03097752,
#           0.03303529,  0.04536482],
#         [-0.04993763, -0.00936762, -0.03285591, -0.00137503,
#          -0.04254065, -0.00520714, -0.02135353,  0.02181954,
#           0.02116657,  0.02434163],
#         [-0.03057574,  0.01116729, -0.03806347,  0.03410003,
#          -0.0133304 , -0.04821406, -0.02268374, -0.02588072,
#          -0.00587511, -0.04017673],
#         [ 0.0029979 ,  0.04305224,  0.04474748, -0.00748608,
#          -0.03005732,  0.02354633, -0.00489905, -0.02228575,
#           0.03264082,  0.0431743 ],
#         [ 0.03630084, -0.01648297,  0.02003438,  0.00955741,
#          -0.0211835 , -0.0315058 ,  0.02355404, -0.04800181,
#           0.03998161,  0.02602788],
#         [-0.04993763, -0.00936762, -0.03285591, -0.00137503,
#          -0.04254065, -0.00520714, -0.02135353,  0.02181954,
#           0.02116657,  0.02434163],
#         [-0.04222417, -0.03720592, -0.02691523, -0.02534245,
#          -0.0433336 ,  0.04460852,  0.0320389 , -0.03661418,
#           0.03061563,  0.01801929]]], dtype=float32)
